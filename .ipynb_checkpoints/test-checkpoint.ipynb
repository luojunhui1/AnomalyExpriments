# %%
from utils.cluster import *
from utils.geo import *
from utils.loaddata import *
from utils.utils import *

# %%
data = get_h5data("./data/UnicomBJ_flows.h5")
print(data.shape)
print("time interval amounts(1 hour): ", data.shape[0])
print("grid horizontal amounts: ", data.shape[2])
print("grid vertical amounts: ", data.shape[3])
# Out:
# (2184, 2, 32, 32)
# time interval amounts(1 hour):  2184
# grid horizontal amounts:  32
# grid vertical amounts:  32

# %%
inflow = data[:, 0, :, :].reshape(len(data), -1).T
outflow = data[:, 0, :, :].reshape(len(data), -1).T

# normalize
inflow_norm = norm_by_row(inflow)
outflow_norm = norm_by_row(outflow)

print("inflow_norm shape: ", inflow_norm.shape, \
    "outflow_norm shape: ", outflow_norm.shape)
# Out:
# inflow_norm shape:  (1024, 2184) outflow_norm shape:  (1024, 2184)

# %%
# cluster expriments
import matplotlib.pyplot as plt
from numpy import *
from tqdm import *

cluster_methods = ['kmeans', 'kpp_means', 'bi_kmeans', 'dbscan', 'optics']

# kmeans耗时过长，在k=12时就呈现出无法收敛的状态，平均每次聚类耗费时间10m以上
# kmeans_sse = []
# kmeans_stds = []
# for i in trange(3, 30):
#     cur_sses = []
#     for j in trange(0, 10):
#         centroid, cluster_assment = kmeans(inflow_norm, i)
#         cur_sses.append(sum(cluster_assment[:,1]))
#     kmeans_sse.append(sum(cur_sses)/10)
#     kmeans_stds.append(std(cur_sses, ddof=1))

# %%
kmeans_times = [4.26, 6.08, 10.72, 13.46, 16.25, 24.69, 24.61, 32.11, 26.86, 32.14, 35.20, 34.50, 42.94, 41.96, 35.52, 46.26, 43.34, 52.29, 40.97, 51.54, 66.32, 57.84, 57.45, 53.48, 64.21, 53.36, 74.43]

fig = plt.figure(figsize=(20, 20))
_, ax = plt.subplots()
ax.plot(range(3, 30), kmeans_sse, c='r', ls=':', marker='s', label='sse')
ax.plot(range(3, 30), kmeans_stds, c='b', ls=':', marker='^', label='std')
ax.set_xlabel('k')

ax1 = ax.twinx()
ax1.plot(range(3, 30), kmeans_times, c='y', ls=':', marker='.', label='time cost')
ax1.set_ylabel('time(s)')

plt.legend()
plt.show()

# %%
np.save('kmeans_sse.npy',kmeans_sse)
np.save('kmeans_stds.npy',kmeans_stds)

# %%
kpp_means_sse = []
kpp_means_stds = []
for i in trange(3, 30):
    cur_sses = []
    for j in trange(0, 10):
        centroid, cluster_assment = kpp_means(mat(inflow_norm), i)
        cur_sses.append(sum(cluster_assment[:,1]))
    kpp_means_sse.append(sum(cur_sses)/10)
    kpp_means_stds.append(std(cur_sses, ddof=1))

# %%
fig = plt.figure(figsize=(20, 20))
_, ax = plt.subplots()
ax.plot(range(3, 30), kpp_means_sse, c='r', ls=':', marker='s', label='sse')
ax.plot(range(3, 30), kpp_means_stds, c='b', ls=':', marker='^', label='std')
ax.set_xlabel('k')

plt.legend()
plt.show()

# %%
np.save('kpp_means_sse.npy',kpp_means_sse)
np.save('kpp_means_stds.npy',kpp_means_stds)

# %%
bi_kmeans_sse = []
bi_kmeans_stds = []
for i in trange(3, 30):
    cur_sses = []
    for j in trange(0, 10):
        centroid, cluster_assment = bi_kmeans(mat(inflow_norm), i)
        cur_sses.append(sum(cluster_assment[:,1]))
    bi_kmeans_sse.append(sum(cur_sses)/10)
    bi_kmeans_stds.append(std(cur_sses, ddof=1))

# %%
fig = plt.figure(figsize=(20, 20))
_, ax = plt.subplots()
ax.plot(range(3, 30), bi_kmeans_sse, c='r', ls=':', marker='s', label='sse')
ax.plot(range(3, 30), bi_kmeans_stds, c='b', ls=':', marker='^', label='std')
ax.set_xlabel('k')

plt.legend()
plt.show()

# %%
np.save('bi_kmeans-cluster_assment.npy', cluster_assment)
np.save('bi_kmeans-centroid.npy', centroid)
np.save('bi_kmeans_sse.npy', bi_kmeans_sse)
np.save('bi_kmeans_stds.npy', bi_kmeans_stds)

# %%
dbscan_sse = []
dbscan_stds = []
for i in range(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur_sses = []
        for k in range(10):
            centroid, cluster_assment=dbscan_lib(inflow_norm, eps = j, minPts=i)
            cur_sses.append(sum(cluster_assment[:,1]))
        dbscan_sse.append(sum(cur_sses)/10)
        dbscan_stds.append(std(cur_sses, ddof=1))

# %%
fig = plt.figure(figsize=(20, 20))
_, ax = plt.subplots()
ax.plot(range(0, 80), dbscan_sse, c='r', ls=':', marker='s', label='sse')
ax.set_xlabel('min sample points')
plt.xticks(range(0, 80, 10), tuple(range(2, 10)))
plt.legend()
plt.show()

# %%
np.save('dbscan_sse.npy', dbscan_sse)
np.save('dbscan_stds.npy', dbscan_stds)

# %%
optics_sse = []
optics_stds = []
for i in range(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur_sses = []
        for k in range(10):
            centroid, cluster_assment=optics_lib(inflow_norm, eps = j, minPts=i)
            cur_sses.append(sum(cluster_assment[:,1]))
        optics_sse.append(sum(cur_sses)/10)
        optics_stds.append(std(cur_sses, ddof=1))

# %%
class_nums = [102, 25, 13, 7, 6, 3, 5, 4]
fig = plt.figure(figsize=(20, 20))
_, ax = plt.subplots()
ax.plot(range(0, 80, 10), [optics_sse[i] for i in range(0, 80, 10)] , c='r', ls=':', marker='s', label='sse')
# ax.plot(range(0, 80), optics_stds, c='b', ls=':', marker='^', label='std')
ax2 = ax.twinx()
ax2.plot(range(0, 80, 10), class_nums, c='b', ls=':', marker='^', label='std')

ax.set_xlabel('min sample points')
plt.xticks(range(0, 80, 10), tuple(range(2, 10)))

plt.legend()
plt.show()

# %%
np.save('optics_sse.npy', optics_sse)
np.save('optics_stds.npy', optics_stds)

# %%
import matplotlib.pyplot as plt
sses = []
stds = []

colors = ['#f1c40f', '#c0392b', '#8e44ad', '#27ae60', '#2c3e50']

plt.rcParams.update({'font.size':10})

fig = plt.figure(figsize=(12, 10))
ax1 = fig.add_subplot(1, 1, 1)
for i in range(3):
    cur = load(cluster_methods[i] + '_sse.npy')
    ax1.plot(range(3, 30), cur, c=colors[i], ls=':', marker='s', label=cluster_methods[i])
    ax1.set_xlabel('K', fontsize=15)
    ax1.set_ylabel('SSE', fontsize=15)

ax1.legend(loc='lower left')
ax1.axhline(y=1214, c='r', ls='--', lw=2)

# ax2 = fig.add_subplot(1, 2, 2)
ax2 = ax1.twiny()
for i in range(3, 5):
    cur = load(cluster_methods[i] + '_sse.npy')
    mins = [min(cur[i:i + 10]) for i in range(0, 80, 10)]
    ax2.plot(range(2, 10), mins, c=colors[i], ls=':', marker='^', label=cluster_methods[i])
    ax2.set_xlabel('Min Sample Points', fontsize=15)
    # ax2.set_ylabel('SSE')

ax2.legend()

# %%
bi_kmeans_sse = load('bi_kmeans_sse.npy')
min_sse = min(bi_kmeans_sse)
min_k = argmin(bi_kmeans_sse)
print(min_sse, min_k)
# Out:
# 1214.86516932395 24

# %%
centroid, cluster_assment = bi_kmeans(mat(inflow_norm), min_k)
save('inflow_center_h.npy', centroid)
save('inflow_label_h.npy', cluster_assment[:, 0])
save('inflow_std_h.npy', sqrt(cluster_assment[:, 1]))

# %%
centroid, cluster_assment = bi_kmeans(mat(outflow_norm), min_k)
save('outflow_center_h.npy', centroid)
save('outflow_label_h.npy', cluster_assment[:, 0])
save('outflow_std_h.npy', sqrt(cluster_assment[:, 1]))

# %%
inflow_mins = [min(inflow[i]) for i in range(inflow.shape[0])]
save('inflow_mins.npy', inflow_mins)
outflow_mins = [min(outflow[i]) for i in range(outflow.shape[0])]
save('outflow_mins.npy', outflow_mins)
print(len(inflow_mins), ", ", len(outflow_mins))
# Out:
# 1024 ,  1024

# %%
inflow_norm_day = []
for i in range(0, inflow_norm.shape[0]):
    inflow_norm_day.append([sum(inflow_norm[i, j:j + 24]) for j in range(0, inflow_norm.shape[1], 24)])
inflow_norm_day = np.array(inflow_norm_day)
inflow_norm_day.shape
# Out:
# (1024, 91)

# %%
kpp_means_sse = []
for i in trange(3, 30):
    cur = []
    for j in range(0, 10):
        centroid, cluster_labels, cur_sse = kmeans_lib(mat(inflow_norm_day), i)
        cur.append(cur_sse)
    kpp_means_sse.append(sum(cur)/10)
np.save('kpp_means_sse_d.npy', kpp_means_sse)

# %%
np.save('kpp_means_sse_d.npy', kpp_means_sse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-40535f95eb8c> in <module>
# ----> 1 np.save('kpp_means_sse_d.npy', kpp_means_sse)
#
# NameError: name 'kpp_means_sse' is not defined

# %%
bi_kmeans_sse = []
for i in trange(3, 50):
    cur = []
    for j in range(0, 10):
        centroid, assment = bi_kmeans_lib(mat(inflow_norm_day), i)
        cur.append(sum(assment[:, 1]))
    bi_kmeans_sse.append(sum(cur)/10)
np.save('bi_kmeans_sse_d.npy', bi_kmeans_sse)

# %%
dbscan_sse = []
for i in trange(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur = []
        for k in range(10):
            centroid, assment = bi_kmeans_lib(inflow_norm_day, eps=j, minPts=i)
            cur.append(sum(assment[:, 1]))
        dbscan_sse.append(sum(cur)/10)
np.save('dbscan_sse_d.npy', bi_kmeans_sse)

optics_sse = []
for i in trange(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur = []
        for k in range(10):
            centroid, assment = optics_lib(inflow_norm_day, eps=j, minPts=i)
            cur.append(sum(assment[:, 1]))
        optics_sse.append(sum(cur)/10)
np.save('optics_sse_d.npy', optics_sse)

# %%
# kpp_means_sse = []
# for i in trange(3, 30):
#     cur = []
#     for j in range(0, 10):
#         centroid, cluster_labels, cur_sse = kmeans_lib(mat(inflow_norm_day), i)
#         cur.append(cur_sse)
#     kpp_means_sse.append(sum(cur)/10)
# np.save('kpp_means_sse_d.npy', kpp_means_sse)

# bi_kmeans_sse = []
# for i in trange(3, 30):
#     cur = []
#     for j in range(0, 10):
#         centroid, assment = bi_kmeans_lib(mat(inflow_norm_day), i)
#         cur.append(sum(assment[:, 1]))
#     bi_kmeans_sse.append(sum(cur)/10)
# np.save('bi_kmeans_sse_d.npy', bi_kmeans_sse)

dbscan_sse = []
for i in trange(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur = []
        for k in range(10):
            centroid, assment = dbscan_lib(inflow_norm_day, eps=j, minPts=i)
            cur.append(sum(assment[:, 1]))
        dbscan_sse.append(sum(cur)/10)
np.save('dbscan_sse_d.npy', bi_kmeans_sse)

optics_sse = []
for i in trange(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur = []
        for k in range(10):
            centroid, assment = optics_lib(inflow_norm_day, eps=j, minPts=i)
            cur.append(sum(assment[:, 1]))
        optics_sse.append(sum(cur)/10)
np.save('optics_sse_d.npy', optics_sse)

#=============================================================
inflow_norm_week = []
for i in range(0, inflow_norm.shape[0]):
    inflow_norm_week.append([sum(inflow_norm[i, j:j + 168]) for j in range(0, inflow_norm.shape[1], 168)])
inflow_norm_week = np.array(inflow_norm_week)
inflow_norm_week.shape

kpp_means_sse = []
for i in trange(3, 30):
    cur = []
    for j in range(0, 10):
        centroid, cluster_labels, cur_sse = kmeans_lib(mat(inflow_norm_week), i)
        cur.append(cur_sse)
    kpp_means_sse.append(sum(cur)/10)
np.save('kpp_means_sse_w.npy', kpp_means_sse)

bi_kmeans_sse = []
for i in trange(3, 30):
    cur = []
    for j in range(0, 10):
        centroid, assment = bi_kmeans_lib(mat(inflow_norm_week), i)
        cur.append(sum(assment[:, 1]))
    bi_kmeans_sse.append(sum(cur)/10)
np.save('bi_kmeans_sse_w.npy', bi_kmeans_sse)

dbscan_sse = []
for i in trange(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur = []
        for k in range(10):
            centroid, assment = dbscan_lib(inflow_norm_week, eps=j, minPts=i)
            cur.append(sum(assment[:, 1]))
        dbscan_sse.append(sum(cur)/10)
np.save('dbscan_sse_w.npy', bi_kmeans_sse)

optics_sse = []
for i in trange(2, 10):
    for j in [0.5, 1., 1.5, 2., 2.5, 3., 3.5, 4., 4.5, 5.]:
        cur = []
        for k in range(10):
            centroid, assment = optics_lib(inflow_norm_week, eps=j, minPts=i)
            cur.append(sum(assment[:, 1]))
        optics_sse.append(sum(cur)/10)
np.save('optics_sse_w.npy', optics_sse)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# sse_split, sse_nonsplit 0.0 715.9771602795199
# the bestCentToSplit is:  9
# the len of bestClustAss is:  5
# sse_split, sse_nonsplit 86094.74896084383 0.0
# the bestCentToSplit is:  0
# the len of bestClustAss is:  1024
# sse_split, sse_nonsplit 37872.94092770867 86094.74896084383
# sse_split, sse_nonsplit 22606.90288434417 0.0
# the bestCentToSplit is:  1
# the len of bestClustAss is:  597
# sse_split, sse_nonsplit 67153.24442807 22606.90288434417
# sse_split, sse_nonsplit 15933.729965338656 22606.90288434417
# sse_split, sse_nonsplit 10063.641757031543 0.0
# the bestCentToSplit is:  2
# the len of bestClustAss is:  239
# sse_split, sse_nonsplit 35351.43794994916 10063.641757031543
# sse_split, sse_nonsplit 9704.93028980531 10063.641757031543
# sse_split, sse_nonsplit 4482.082245376223 9812.941088881236
# sse_split, sse_nonsplit 8355.959910437075 250.700668150305
# the bestCentToSplit is:  3
# the len of bestClustAss is:  154
# sse_split, sse_nonsplit 23182.99359374933 8606.660578587382
# sse_split, sse_nonsplit 17529.87103044186 8606.66057858738
# sse_split, sse_nonsplit 4106.0778813043635 8355.959910437075
# sse_split, sse_nonsplit 2051.3808169561507 7572.8282829681675
# sse_split, sse_nonsplit 2442.717996349941 1284.5329637695186
# the bestCentToSplit is:  4
# the len of bestClustAss is:  86
# sse_split, sse_nonsplit 23243.728504664345 3727.2509601194597
# sse_split, sse_nonsplit 13476.057180791013 3727.2509601194597
# sse_split, sse_nonsplit 7151.219222389709 3476.550291969155
# sse_split, sse_nonsplit 817.6080157041187 2693.4186645002465
# sse_split, sse_nonsplit 1661.7197583440845 3486.637070617907
# sse_split, sse_nonsplit 1765.7053522323474 1525.1468532710717
# the bestCentToSplit is:  5
# the len of bestClustAss is:  43
# sse_split, sse_nonsplit 49992.73992533695 3290.852205503419
# sse_split, sse_nonsplit 25308.251193598506 3290.852205503419
# sse_split, sse_nonsplit 3571.3202973736593 3040.1515373531147
# sse_split, sse_nonsplit 633.9856060951475 2257.019909884206
# sse_split, sse_nonsplit 935.4723746615266 3050.238316001866
# sse_split, sse_nonsplit 230.08768020670223 2969.98564666559
# sse_split, sse_nonsplit 690.5490639557725 1846.0134121089009
# the bestCentToSplit is:  6
# the len of bestClustAss is:  31
# sse_split, sse_nonsplit 22390.255473581776 2536.5624760646733
# sse_split, sse_nonsplit 25209.418279865396 2536.5624760646733
# sse_split, sse_nonsplit 1315.8524019433444 2285.861807914368
# sse_split, sse_nonsplit 0.0 1502.7301804454596
# sse_split, sse_nonsplit 938.2778902190898 2295.9485865631204
# sse_split, sse_nonsplit 375.1578910894236 2215.6959172268444
# sse_split, sse_nonsplit 274.9781131719682 2536.5624760646733
# sse_split, sse_nonsplit 402.6870051973765 1846.0134121089009
# the bestCentToSplit is:  3
# the len of bestClustAss is:  68
# sse_split, sse_nonsplit 32861.84271116302 1502.7301804454596
# sse_split, sse_nonsplit 14670.286292342127 1502.7301804454596
# sse_split, sse_nonsplit 2561.713934945162 1252.0295122951547
# sse_split, sse_nonsplit 1016.694505650545 250.700668150305
# sse_split, sse_nonsplit 526.8855015832986 250.700668150305
# sse_split, sse_nonsplit 83.89431689713327 250.700668150305
# sse_split, sse_nonsplit 58.34795725284306 250.700668150305
# sse_split, sse_nonsplit 0.0 250.700668150305
# the bestCentToSplit is:  22
# the len of bestClustAss is:  2
# sse_split, sse_nonsplit 40788.27176287437 250.700668150305
# sse_split, sse_nonsplit 18382.036624359345 250.700668150305
# sse_split, sse_nonsplit 3822.4074672145357 0.0
# sse_split, sse_nonsplit 1934.9495852218274 250.700668150305
# sse_split, sse_nonsplit 397.67870069587667 250.700668150305
# sse_split, sse_nonsplit 241.06713475091746 250.700668150305
# sse_split, sse_nonsplit 291.89833924779424 250.700668150305
# sse_split, sse_nonsplit 179.64549984128269 250.700668150305
# the bestCentToSplit is:  7
# the len of bestClustAss is:  11
# sse_split, sse_nonsplit 52850.061875265754 430.34616799158766
# sse_split, sse_nonsplit 21668.93449148418 430.3461679915876
# sse_split, sse_nonsplit 3550.7075186161887 179.64549984128269
# sse_split, sse_nonsplit 1055.9355492768495 430.34616799158766
# sse_split, sse_nonsplit 613.0791644998687 430.34616799158766
# sse_split, sse_nonsplit 542.9293480935845 430.34616799158766
# sse_split, sse_nonsplit 132.82873620271815 430.34616799158766
# sse_split, sse_nonsplit 17.979786626921967 430.34616799158766
# sse_split, sse_nonsplit 0.0 250.700668150305
# the bestCentToSplit is:  25
# the len of bestClustAss is:  7
# sse_split, sse_nonsplit 40879.48512795172 250.700668150305
# sse_split, sse_nonsplit 16429.401903202845 250.700668150305
# sse_split, sse_nonsplit 3445.055394623381 0.0
# sse_split, sse_nonsplit 1133.9208709867648 250.700668150305
# sse_split, sse_nonsplit 1376.8791095394783 250.700668150305
# sse_split, sse_nonsplit 151.91532339683565 250.700668150305
# sse_split, sse_nonsplit 324.960289902585 250.700668150305
# sse_split, sse_nonsplit 0.0 250.700668150305
# sse_split, sse_nonsplit 69.43086276903341 250.700668150305
# the bestCentToSplit is:  7
# the len of bestClustAss is:  4
# sse_split, sse_nonsplit 46620.99988432834 250.700668150305
# 100%|██████████| 27/27 [1:12:01<00:00, 160.04s/it]
# sse_split, sse_nonsplit 20048.042279226676 250.700668150305
# sse_split, sse_nonsplit 4726.282397451992 0.0
# sse_split, sse_nonsplit 612.2046679624286 250.700668150305
# sse_split, sse_nonsplit 397.67870069587667 250.700668150305
# sse_split, sse_nonsplit 172.46996536731723 250.700668150305
# sse_split, sse_nonsplit 298.3646185029181 250.700668150305
# sse_split, sse_nonsplit 0.0 250.700668150305
# sse_split, sse_nonsplit 62.93284495376275 250.700668150305
# the bestCentToSplit is:  7
# the len of bestClustAss is:  3
#   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-075659945420> in <module>
#      22         cur = []
#      23         for k in range(10):
# ---> 24             centroid, assment = bi_kmeans_lib(inflow_norm_day, eps=j, minPts=i)
#      25             cur.append(sum(assment[:, 1]))
#      26         dbscan_sse.append(sum(cur)/10)
#
# TypeError: bi_kmeans_lib() got an unexpected keyword argument 'eps'
